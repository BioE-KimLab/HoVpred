# %%
import pandas as pd
import rdkit
from collections import Counter

# %% [markdown]
# # Read DataFrame

# %%
df = pd.read_csv('HoV_results.csv')
oxygenate_condition = (df.smiles.str.contains('O')) | (df.smiles.str.contains('o'))

df_hydrocarbons = df[ ~oxygenate_condition ]
df_oxygenates = df[oxygenate_condition]
print(len(df_hydrocarbons.smiles.unique()), len(df_oxygenates.smiles.unique()))
# Out:
# 3153 4247

# %% [markdown]
# # Oxygenates

# %%
def oxygenates_FG(smiles):
    mol = rdkit.Chem.MolFromSmiles(smiles)
    
    FG_names = ['Acyclic_Ester', 'Cyclic_Ester', 
                'Acyclic_Ether', 'Cyclic_Ether',
                'COOH', '0ry_Alcohol', '1ry_Alcohol', '2ry_Alcohol', '3ry_Alcohol', 
                'Carbonyl1', 'Carbonyl2', 'peroxide', 'phenolics']
    
    SMARTS_list = ['[CX3;!R](=[OX1])O[C,c]', '[CX3;R](=[OX1])[O;R][C,c]',
                   '[OD2;!R]([#6])[#6]', '[OD2;R]([#6;R])[#6;R]',
                   '*-C(=O)[O;D1]', '[CH3]-[O;D1]', '[CH2]-[O;D1]', '[CH1]-[O;D1]', '[CH0]-[O;D1]',
                    '*-C(=O)-[C;D1]', '*=[O;D1]', '[O]-[O]', '[c;R]-[O;D1]'
                  ]
    FG_SMARTS = [ rdkit.Chem.MolFromSmarts(x) for x in SMARTS_list  ]
    
    
    FG_count = [len(mol.GetSubstructMatches(x)) for x in FG_SMARTS]
    
    if sum(FG_count) == 0:
        if smiles == 'O' or smiles == '[C-]#[O+]':
            return 'water or carbon monoxide'
        else:
            return 'Furanics'
    else:
        FG_names_lumped = ['Acyclic_Ester', 'Cyclic_Ester', 
                            'Acyclic_Ether', 'Cyclic_Ether', 'COOH',
                            'Alcohol', 'Carbonyls', 'peroxide', 'phenolic']
        FG_count = FG_count[0:5] + [sum(FG_count[5:9])] + [sum(FG_count[9:11])] + FG_count[11:]
        FG_index = next((i for i, x in enumerate(FG_count) if x), None)
        
        return FG_names_lumped[FG_index]

# %%
result = []
for smi in df_oxygenates.smiles.unique():
    fg = oxygenates_FG(smi)
    result.append([smi,fg])
#print('.'.join([ result_smi[i] for i, fg in enumerate(result_fg) if fg == 'Carbonyls' ]))

# %% [markdown]
# # Hydrocarbons

# %%
def hydrocarbons_FG(smiles):
    mol = rdkit.Chem.MolFromSmiles(smiles)
    
    FG_names = [  'Alkyne', 'Alkene', 'FusedRing-Aromatics', 'FusedRing-Cycloalkanes'  ]
    SMARTS_list = [ '[C]#[C]', '[C]=[C]', '[cR2]', '[CR2]'  ]
    
    FG_SMARTS = [ rdkit.Chem.MolFromSmarts(x) for x in SMARTS_list  ]
    FG_count = [len(mol.GetSubstructMatches(x)) for x in FG_SMARTS]
 
    FG_index = next((i for i, x in enumerate(FG_count) if x), None)

    if sum(FG_count) != 0:
        return FG_names[FG_index]
    else:
        if '1' in smiles:
            if 'c' in smiles:
                return 'Aromatics'
            else:
                return 'Cycloalkanes'
        else:
            return 'Alkane'

# %%
for smi in df_hydrocarbons.smiles.unique():
    fg = hydrocarbons_FG(smi)
    result.append([smi,fg])

result
# Out:
# [['C#CC(=O)OC', 'Acyclic_Ester'],
#  ['C#CC(=O)OCC', 'Acyclic_Ester'],
#  ['C#CC(=O)Oc1ccc(C(C)(C)c2ccc(OC(=O)C#C)cc2)cc1', 'Acyclic_Ester'],
#  ['C#CC(=O)Oc1ccc(OC(=O)C#C)cc1', 'Acyclic_Ester'],
#  ['C#CC(=O)Oc1ccc(Oc2ccc(OC(=O)C#C)cc2)cc1', 'Acyclic_Ester'],
#  ['C#CC(=O)Oc1ccc2ccc(OC(=O)C#C)cc2c1', 'Acyclic_Ester'],
#  ['C#CC(=O)Oc1ccc2cccc(OC(=O)C#C)c2c1', 'Acyclic_Ester'],
#  ['C#CC(=O)Oc1cccc2c(OC(=O)C#C)cccc12', 'Acyclic_Ester'],
#  ['C#CC(C)(C)O', 'Alcohol'],
#  ['C#CC(C)(O)CC', 'Alcohol'],
#  ['C#CC(C)(O)CC(C)C', 'Alcohol'],
#  ['C#CC(C)(O)CCC', 'Alcohol'],
#  ['C#CC(C)(O)CCC=C(C)C', 'Alcohol'],
#  ['C#CC(C)(O)CCCC(C)C', 'Alcohol'],
#  ['C#CC(C)(O)CCCC(C)CCCC(C)C', 'Alcohol'],
#  ['C#CC(C)(O)CCCC(C)CCCC(C)CCCC(C)C', 'Alcohol'],
#  ['C#CC(C)(O)c1ccccc1', 'Alcohol'],
#  ['C#CC(C)C(C)(O)CCCC(C)C', 'Alcohol'],
#  ['C#CC(C)O', 'Alcohol'],
#  ['C#CC(O)(CC)CC', 'Alcohol'],
#  ['C#CC(O)C1CC=CCC1', 'Alcohol'],
#  ['C#CC(O)C1CC=CCC1C', 'Alcohol'],
#  ['C#CC(OC(C)=O)C1CC=CCC1', 'Acyclic_Ester'],
#  ['C#CC(OC(C)=O)C1CC=CCC1C', 'Acyclic_Ester'],
#  ['C#CC1(O)CCCCC1', 'Alcohol'],
#  ['C#CC1(OC(=O)c2ccc(C3CCCCC3)cc2)CCC2C3CCC4=CC(=O)CCC4C3CCC21C',
#   'Acyclic_Ester'],
#  ['C#CC=O', 'Carbonyls'],
#  ['C#CCC#CCCCCCC(=O)O', 'COOH'],
#  ['C#CCC(C)(O)C=C', 'Alcohol'],
#  ['C#CCC(C)(O)CC#C', 'Alcohol'],
#  ['C#CCC(C)O', 'Alcohol'],
#  ['C#CCC(O)C(C)C', 'Alcohol'],
#  ['C#CCC(O)C=C', 'Alcohol'],
#  ['C#CCC(O)CC', 'Alcohol'],
#  ['C#CCC(O)CC#C', 'Alcohol'],
#  ['C#CCC(O)CCC', 'Alcohol'],
#  ['C#CCCCC(=O)c1cc(C(C)(C)C)c(O)c(C(C)(C)C)c1', 'Carbonyls'],
#  ['C#CCCCCC(C(=O)O)C(=O)O', 'COOH'],
#  ['C#CCCCCC(C(=O)OCC)C(=O)OCC', 'Acyclic_Ester'],
#  ['C#CCCCCCCCC(=O)O', 'COOH'],
#  ['C#CCCCCCCCCC(=O)O', 'COOH'],
#  ['C#CCCCCCCCCCO', 'Alcohol'],
#  ['C#CCCCCO', 'Alcohol'],
#  ['C#CCCCO', 'Alcohol'],
#  ['C#CCCO', 'Alcohol'],
#  ['C#CCO', 'Alcohol'],
#  ['C#CCOC(C)=O', 'Acyclic_Ester'],
#  ['C#CCOC(C)c1ccc(OC)cc1', 'Acyclic_Ether'],
#  ['C#COC', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCCCCCCCCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCCCCCCCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCCCCCCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCCCCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCCCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccc(OCCOc2ccc(C#C)cc2)cc1', 'Acyclic_Ether'],
#  ['C#Cc1ccccc1O', 'phenolic'],
#  ['C#Cc1ccco1', 'Furanics'],
#  ['C(CCC1CO1)CC1CO1', 'Cyclic_Ether'],
#  ['C(CCCOC1CCCCC1)CCOC1CCCCC1', 'Acyclic_Ether'],
#  ['C(CCCOCC1CCC1)CCOCC1CCC1', 'Acyclic_Ether'],
#  ['C(CCCOCC1CCCC1)CCOCC1CCCC1', 'Acyclic_Ether'],
#  ['C(CCCOCCC1CCCCC1)CCOCCC1CCCCC1', 'Acyclic_Ether'],
#  ['C1=CC(OC2C=CCC2)CC1', 'Acyclic_Ether'],
#  ['C1=CC2OC1c1ccccc12', 'Cyclic_Ether'],
#  ['C1=CCOC1', 'Cyclic_Ether'],
#  ['C1=COCC1', 'Cyclic_Ether'],
#  ['C1=COCCC1', 'Cyclic_Ether'],
#  ['C1C2CC3CC(CC1O3)O2', 'Cyclic_Ether'],
#  ['C1C2CC3CC1OC(O2)O3', 'Cyclic_Ether'],
#  ['C1CC2(CCCC3(C1)OCCO3)OCCO2', 'Cyclic_Ether'],
#  ['C1CC23CCC2(C1)O3', 'Cyclic_Ether'],
#  ['C1CC2CCC1COC2', 'Cyclic_Ether'],
#  ['C1CC2CCC1O2', 'Cyclic_Ether'],
#  ['C1CC2OC2C1', 'Cyclic_Ether'],
#  ['C1CCC2(C1)OCCO2', 'Cyclic_Ether'],
#  ['C1CCC2(CC1)OCCO2', 'Cyclic_Ether'],
#  ['C1CCC2(CCCCC3(C1)OCCO3)OCCO2', 'Cyclic_Ether'],
#  ['C1CCC2(CCCCCC3(CC1)OCCO3)OCCO2', 'Cyclic_Ether'],
#  ['C1CCC2OC2C1', 'Cyclic_Ether'],
#  ['C1CCC2OC2CC1', 'Cyclic_Ether'],
#  ['C1CCCC2(CCCCCCC3(CC1)OCCO3)OCCO2', 'Cyclic_Ether'],
#  ['C1CCCC2(CCCCCCCC3(CCC1)OCCO3)OCCO2', 'Cyclic_Ether'],
#  ['C1CCCC2OC2CC1', 'Cyclic_Ether'],
#  ['C1CCCCC2(CCCCCCCCC3(CCC1)OCCO3)OCCO2', 'Cyclic_Ether'],
#  ['C1CCCCC2(CCCCCCCCCC3(CCCC1)OCCO3)OCCO2', 'Cyclic_Ether'],
#  ['C1CCCOCC1', 'Cyclic_Ether'],
#  ['C1CCOC1', 'Cyclic_Ether'],
#  ['C1CCOCC1', 'Cyclic_Ether'],
#  ['C1CCOCOC1', 'Cyclic_Ether'],
#  ['C1CCOCOCC1', 'Cyclic_Ether'],
#  ['C1CCOCOCCCCCOCOCC1', 'Cyclic_Ether'],
#  ['C1CCc2c(oc3c2CCCC3)C1', 'Furanics'],
#  ['C1CO1', 'Cyclic_Ether'],
#  ['C1COC1', 'Cyclic_Ether'],
#  ['C1COC2(CCC3(CC2)OCCO3)O1', 'Cyclic_Ether'],
#  ['C1COC2(O1)C1CCC2CC1', 'Cyclic_Ether'],
#  ['C1COCCO1', 'Cyclic_Ether'],
#  ['C1COCCOCCOCCO1', 'Cyclic_Ether'],
#  ['C1COCCOCCOCCOCCO1', 'Cyclic_Ether'],
#  ['C1COCCOCCOCCOCCOCCO1', 'Cyclic_Ether'],
#  ['C1COCCOCCOCCOCCOCCOCCOCCO1', 'Cyclic_Ether'],
#  ['C1COCO1', 'Cyclic_Ether'],
#  ['C1COCOC1', 'Cyclic_Ether'],
#  ['C1COCOCCO1', 'Cyclic_Ether'],
#  ['C1OC1C1CO1', 'Cyclic_Ether'],
#  ['C1OCC2(CO1)COCOC2', 'Cyclic_Ether'],
#  ['C1OCOCO1', 'Cyclic_Ether'],
#  ['C1OCOCOCO1', 'Cyclic_Ether'],
#  ['C1OCOCOCOCO1', 'Cyclic_Ether'],
#  ['C=C(C(=O)OC)C(C)(C)C', 'Acyclic_Ester'],
#  ['C=C(C)C#CC(C)(C)O', 'Alcohol'],
#  ['C=C(C)C(=C=CCC(C)C)C(C)(C)O', 'Alcohol'],
#  ['C=C(C)C(=C=CCCC)C(C)O', 'Alcohol'],
#  ['C=C(C)C(=O)O', 'COOH'],
#  ['C=C(C)C(=O)OC', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OC(C)C', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OC1CCCCC1', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCC', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCC1CO1', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCCC', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCCCC', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCCCCC', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCCCCCCCC', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCCO', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)OCc1ccccc1', 'Acyclic_Ester'],
#  ['C=C(C)C(=O)Oc1ccc(C(=O)O)cc1', 'Acyclic_Ester'],
#  ['C=C(C)C(C)=O', 'Carbonyls'],
#  ['C=C(C)C(CC=C(C)C)C(C)=O', 'Carbonyls'],
#  ['C=C(C)C(O)CC', 'Alcohol'],
#  ['C=C(C)C1CC=C(C)C(=O)C1', 'Carbonyls'],
#  ['C=C(C)C1CCC2(C)OC2C1', 'Cyclic_Ether'],
#  ['C=C(C)C1Cc2c(ccc3c2OC2COc4cc(OC)c(OC)cc4C2C3=O)O1', 'Acyclic_Ether'],
#  ['C=C(C)C=CCC(=O)OC', 'Acyclic_Ester'],
#  ['C=C(C)C=CCCO', 'Alcohol'],
#  ['C=C(C)C=O', 'Carbonyls'],
#  ['C=C(C)CC(C)(C)CC(=O)O', 'COOH'],
#  ['C=C(C)CC(C)=O', 'Carbonyls'],
#  ['C=C(C)CC=CCCC(C)O', 'Alcohol'],
#  ['C=C(C)CCC=O', 'Carbonyls'],
#  ['C=C(C)CCCC(C)CC=O', 'Carbonyls'],
#  ['C=C(C)CCO', 'Alcohol'],
#  ['C=C(C)CCOC(C)=O', 'Acyclic_Ester'],
#  ['C=C(C)COC', 'Acyclic_Ether'],
#  ['C=C(C)COC(C)(C)C', 'Acyclic_Ether'],
#  ['C=C(C)COCC(=C)C', 'Acyclic_Ether'],
#  ['C=C(C)COCCC', 'Acyclic_Ether'],
#  ['C=C(C)COc1ccccc1', 'Acyclic_Ether'],
#  ['C=C(C)OC', 'Acyclic_Ether'],
#  ['C=C(C)OC(=C)CC(C)C', 'Acyclic_Ether'],
#  ['C=C(C)OC(C)=O', 'Acyclic_Ester'],
#  ['C=C(C)OCC', 'Acyclic_Ether'],
#  ['C=C(C)OCCCC', 'Acyclic_Ether'],
#  ['C=C(C=O)CCCC', 'Carbonyls'],
#  ['C=C(CC(=O)O)C(=O)O', 'COOH'],
#  ['C=C(CC(C)(C)C)OC', 'Acyclic_Ether'],
#  ['C=C(CC)OCC', 'Acyclic_Ether'],
#  ['C=C(CC)OCC(C)(C)C', 'Acyclic_Ether'],
#  ['C=C(CCOC(C)=O)c1ccccc1', 'Acyclic_Ester'],
#  ['C=C(Cc1ccccc1)OC', 'Acyclic_Ether'],
#  ['C=C(OC(C)=O)c1ccccc1', 'Acyclic_Ester'],
#  ['C=C(OC(C)C)C(C)C', 'Acyclic_Ether'],
#  ['C=C(OC(C)CC)C(C)C', 'Acyclic_Ether'],
#  ['C=C(OC)C(C)C(=O)OC', 'Acyclic_Ester'],
#  ['C=C(OC)C(C)C(C)=O', 'Acyclic_Ether'],
#  ['C=C(OC)C(OC)C(=O)OC', 'Acyclic_Ester'],
#  ['C=C(OCC(C)(C)C)C(C)C', 'Acyclic_Ether'],
#  ['C=C1C=C(OC)CC(C)C1', 'Acyclic_Ether'],
#  ['C=C1C=C(OC)CCC1', 'Acyclic_Ether'],
#  ['C=C1CC(=O)O1', 'Cyclic_Ester'],
#  ['C=C1CC(=O)OC1=O', 'Cyclic_Ester'],
#  ['C=C1CCCC1O', 'Alcohol'],
#  ['C=C1CCCCC1O', 'Alcohol'],
#  ['C=C1CCCO1', 'Cyclic_Ether'],
#  ['C=C1CCOCC1', 'Cyclic_Ether'],
#  ['C=C1CCOCO1', 'Cyclic_Ether'],
#  ['C=C1COCO1', 'Cyclic_Ether'],
#  ['C=C=CC(=O)CCC', 'Carbonyls'],
#  ['C=C=CC(C)(O)CC=C', 'Alcohol'],
#  ['C=C=CC(C)=O', 'Carbonyls'],
#  ['C=C=CC(C)O', 'Alcohol'],
#  ['C=C=CC(O)(CC)CC=C', 'Alcohol'],
#  ['C=C=CC(O)(CC=C)C(C)C', 'Alcohol'],
#  ['C=C=CC(O)(CC=C)CCC', 'Alcohol'],
#  ['C=C=CC(O)C(C)C', 'Alcohol'],
#  ['C=C=CC(O)CC', 'Alcohol'],
#  ['C=C=CC(O)CCC', 'Alcohol'],
#  ['C=C=CCO', 'Alcohol'],
#  ['C=C=COC', 'Acyclic_Ether'],
#  ['C=CC#CC(C)(C)OOC(C)(C)C', 'peroxide'],
#  ['C=CC#CCC(C)(O)C=C', 'Alcohol'],
#  ['C=CC#CCC(O)C=C', 'Alcohol'],
#  ['C=CC(=C)OC', 'Acyclic_Ether'],
#  ['C=CC(=O)CC', 'Carbonyls'],
#  ['C=CC(=O)CCC', 'Carbonyls'],
#  ['C=CC(=O)OC', 'Acyclic_Ester'],
#  ['C=CC(=O)OC(C)C', 'Acyclic_Ester'],
#  ['C=CC(=O)OC(C)CC', 'Acyclic_Ester'],
#  ['C=CC(=O)OC(C)CC(C)C', 'Acyclic_Ester'],
#  ['C=CC(=O)OC(C)CCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OC(C)CCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OC(CC)CC', 'Acyclic_Ester'],
#  ['C=CC(=O)OC1CCCCC1', 'Acyclic_Ester'],
#  ['C=CC(=O)OCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['C=CC(=O)OCC(C)CC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCC(CC)CC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCC(CC)CCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCC(C)C', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCC(C)C', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCCCCCCCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCCOCC', 'Acyclic_Ester'],
#  ['C=CC(=O)OCc1ccccc1', 'Acyclic_Ester'],
#  ['C=CC(C)(C)O', 'Alcohol'],
#  ['C=CC(C)(CCC=C(C)C)OC(C)=O', 'Acyclic_Ester'],
#  ['C=CC(C)(O)C(C)CCCC(C)C', 'Alcohol'],
#  ['C=CC(C)(O)CC', 'Alcohol'],
#  ['C=CC(C)(O)CCC', 'Alcohol'],
#  ['C=CC(C)(O)CCC=C(C)C', 'Alcohol'],
#  ['C=CC(C)(O)CCCC(C)CCCC(C)CCCC(C)C', 'Alcohol'],
#  ['C=CC(C)(O)CCCC(C)CCCC(C)CCCC(C)C(C)(C)C', 'Alcohol'],
#  ['C=CC(C)=O', 'Carbonyls'],
#  ['C=CC(C)CC=O', 'Carbonyls'],
#  ['C=CC(C)O', 'Alcohol'],
#  ['C=CC(C)OC(C)=O', 'Acyclic_Ester'],
#  ['C=CC(C)OC(C)CC', 'Acyclic_Ether'],
#  ['C=CC(C=C)C(O)CCCCC', 'Alcohol'],
#  ['C=CC(CC)C(O)C(C=C)CC', 'Alcohol'],
#  ['C=CC(CC)C(O)CCCCC', 'Alcohol'],
#  ['C=CC(O)C(C)C', 'Alcohol'],
#  ['C=CC(O)C1CC=CCC1', 'Alcohol'],
#  ['C=CC(O)C1CC=CCC1C', 'Alcohol'],
#  ['C=CC(O)CC', 'Alcohol'],
#  ['C=CC(O)CCC', 'Alcohol'],
#  ['C=CC(O)c1ccccc1', 'Alcohol'],
#  ['C=CC(OC(C)=O)C1CC=CCC1', 'Acyclic_Ester'],
#  ['C=CC(OC(C)=O)C1CC=CCC1C', 'Acyclic_Ester'],
#  ['C=CC(OC(C)=O)OC(C)=O', 'Acyclic_Ester'],
#  ['C=CC(OC(C=C)C1CC=CCC1)C1CC=CCC1', 'Acyclic_Ether'],
#  ['C=CC(OC(C=C)C1CC=CCC1C)C1CC=CCC1C', 'Acyclic_Ether'],
#  ['C=CC1(C)CCOCO1', 'Cyclic_Ether'],
#  ['C=CC1CCOCO1', 'Cyclic_Ether'],
#  ['C=CC1CO1', 'Cyclic_Ether'],
#  ['C=CC1OCCCO1', 'Cyclic_Ether'],
#  ['C=CC=CC(C)(C)O', 'Alcohol'],
#  ['C=CC=CCC(=O)OC', 'Acyclic_Ester'],
#  ['C=CC=COC', 'Acyclic_Ether'],
#  ['C=CC=COC(C)=O', 'Acyclic_Ester'],
#  ['C=CC=O', 'Carbonyls'],
#  ['C=CCC(C(=O)O)C(=O)O', 'COOH'],
#  ['C=CCC(C)(O)C(C)(C)C', 'Alcohol'],
#  ['C=CCC(C)(O)CC=C', 'Alcohol'],
#  ['C=CCC(C)(O)CCC', 'Alcohol'],
#  ['C=CCC(C)(O)CCCC', 'Alcohol'],
#  ['C=CCC(C)(O)CCCCCC', 'Alcohol'],
#  ['C=CCC(CC)C(C)=O', 'Carbonyls'],
#  ['C=CCC(CC)C(C)O', 'Alcohol'],
#  ['C=CCC(CC=C)C(=O)O', 'COOH'],
#  ['C=CCC(O)(CC)CC', 'Alcohol'],
#  ['C=CCC(O)(CCC)CCC', 'Alcohol'],
#  ['C=CCC(O)C(C)C=C', 'Alcohol'],
#  ['C=CCC(O)C=C', 'Alcohol'],
#  ['C=CCC(O)CC=C', 'Alcohol'],
#  ['C=CCC=CCCC(C)O', 'Alcohol'],
#  ['C=CCCC(=O)C(C)(C)C', 'Carbonyls'],
#  ['C=CCCC(=O)OCC(CC)CCCC', 'Acyclic_Ester'],
#  ['C=CCCC(C)(O)C(C)(C)C', 'Alcohol'],
#  ['C=CCCC(C)=O', 'Carbonyls'],
#  ['C=CCCC(C)O', 'Alcohol'],
#  ['C=CCCC(O)C(C)(C)C', 'Alcohol'],
#  ['C=CCCC=O', 'Carbonyls'],
#  ['C=CCCCC(C)(C)O', 'Alcohol'],
#  ['C=CCCCCC1CO1', 'Cyclic_Ether'],
#  ['C=CCCCCCCCCC(=O)O', 'COOH'],
#  ['C=CCCCCCCCCC(=O)OC', 'Acyclic_Ester'],
#  ['C=CCCCCO', 'Alcohol'],
#  ['C=CCCCO', 'Alcohol'],
#  ['C=CCCO', 'Alcohol'],
#  ['C=CCCOC', 'Acyclic_Ether'],
#  ['C=CCO', 'Alcohol'],
#  ['C=CCOC', 'Acyclic_Ether'],
#  ['C=CCOC(=O)C(=C)C', 'Acyclic_Ester'],
#  ['C=CCOC(=O)CC', 'Acyclic_Ester'],
#  ['C=CCOC(=O)CC(C)=O', 'Acyclic_Ester'],
#  ['C=CCOC(=O)CCCCCCCCCCCCCCC', 'Acyclic_Ester'],
#  ['C=CCOC(=O)c1ccccc1', 'Acyclic_Ester'],
#  ['C=CCOC(=O)c1ccccc1C(=O)OCC=C', 'Acyclic_Ester'],
#  ['C=CCOC(C)(C)C', 'Acyclic_Ether'],
#  ['C=CCOC(C)=O', 'Acyclic_Ester'],
#  ['C=CCOC(C)OCC=C', 'Acyclic_Ether'],
#  ['C=CCOC=C', 'Acyclic_Ether'],
#  ['C=CCOC=O', 'Acyclic_Ester'],
#  ['C=CCOCC', 'Acyclic_Ether'],
#  ['C=CCOCC=C', 'Acyclic_Ether'],
#  ['C=CCOCCCCCCCC', 'Acyclic_Ether'],
#  ['C=CCOc1ccc(O)c2c1C(=O)c1ccccc1C2=O', 'Acyclic_Ether'],
#  ['C=CCOc1cccc2c1C(=O)c1c(OCC=C)cccc1C2=O', 'Acyclic_Ether'],
#  ['C=CCOc1ccccc1', 'Acyclic_Ether'],
#  ['C=CCc1cc(OC)c2c(c1OC)OCO2', 'Acyclic_Ether'],
#  ['C=CCc1ccc(O)c(OC)c1', 'Acyclic_Ether'],
#  ['C=CCc1ccc(OC)c(O)c1', 'Acyclic_Ether'],
#  ['C=CCc1ccc(OC)cc1', 'Acyclic_Ether'],
#  ['C=CCc1ccc2c(c1)OCO2', 'Cyclic_Ether'],
#  ['C=CO', 'Alcohol'],
#  ['C=COC', 'Acyclic_Ether'],
#  ['C=COC(=C)C(C)C', 'Acyclic_Ether'],
#  ['C=COC(=C)CC(C)C', 'Acyclic_Ether'],
#  ['C=COC(=O)C(C)C', 'Acyclic_Ester'],
#  ['C=COC(=O)C=C', 'Acyclic_Ester'],
#  ['C=COC(=O)CC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCC(=O)OC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCC(=O)OC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCC(=O)OC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCC(=O)OCC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCC(=O)OCCC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCC(=O)OCCCC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCC(=O)OCCCCC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCC(=O)OCCCCCC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCCC(=O)OC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCCCCC(=O)OC', 'Acyclic_Ester'],
#  ['C=COC(=O)CCCCCCCCC(=O)OC', 'Acyclic_Ester'],
#  ['C=COC(C)(C)C', 'Acyclic_Ether'],
#  ['C=COC(C)=C(C)C', 'Acyclic_Ether'],
#  ['C=COC(C)=O', 'Acyclic_Ester'],
#  ['C=COC(C)C', 'Acyclic_Ether'],
#  ['C=COC1CCCCC1', 'Acyclic_Ether'],
#  ['C=COC=C', 'Acyclic_Ether'],
#  ['C=COC=O', 'Acyclic_Ester'],
#  ['C=COCC', 'Acyclic_Ether'],
#  ['C=COCC(C)C', 'Acyclic_Ether'],
#  ['C=COCCC', 'Acyclic_Ether'],
#  ['C=COCCCC', 'Acyclic_Ether'],
#  ['C=COCCCCCC', 'Acyclic_Ether'],
#  ['C=COCCCCCC(C)C', 'Acyclic_Ether'],
#  ['C=COCCCCCCC', 'Acyclic_Ether'],
#  ['C=COCCCCCCCC', 'Acyclic_Ether'],
#  ['C=COCCCCCCCCC', 'Acyclic_Ether'],
#  ['C=COCCCCCCCCCC', 'Acyclic_Ether'],
#  ['C=COCCCCOC=C', 'Acyclic_Ether'],
#  ['C=COCCOC', 'Acyclic_Ether'],
#  ['C=COCCOC(C)C', 'Acyclic_Ether'],
#  ['C=COCCOC=C', 'Acyclic_Ether'],
#  ['C=COCCOCC', 'Acyclic_Ether'],
#  ['C=COCCOCC(C)C', 'Acyclic_Ether'],
#  ['C=COCCOCC1CO1', 'Acyclic_Ether'],
#  ['C=COCCOCCC', 'Acyclic_Ether'],
#  ['C=COCCOCCCC', 'Acyclic_Ether'],
#  ['C=COCCOCCOCCO', 'Acyclic_Ether'],
#  ['C=COCCOCCOCCOC=C', 'Acyclic_Ether'],
#  ['C=COc1ccc(C(C)=O)cc1', 'Acyclic_Ether'],
#  ['C=COc1ccc(C)cc1', 'Acyclic_Ether'],
#  ['C=COc1ccc(OC)cc1', 'Acyclic_Ether'],
#  ['C=COc1ccccc1', 'Acyclic_Ether'],
#  ['C=Cc1ccc(C(C)=O)cc1', 'Carbonyls'],
#  ['C=Cc1ccc(OC)cc1', 'Acyclic_Ether'],
#  ['C=Cc1ccc(OCC)cc1', 'Acyclic_Ether'],
#  ['C=Cc1ccccc1O', 'phenolic'],
#  ['C=Cc1ccccc1OC', 'Acyclic_Ether'],
#  ['C=Cc1ccco1', 'Furanics'],
#  ['C=O', 'Carbonyls'],
#  ['CC#CCO', 'Alcohol'],
#  ['CC#COCC', 'Acyclic_Ether'],
#  ['CC(=CC(=O)C(C)C)C(C)C', 'Carbonyls'],
#  ['CC(=CC(=O)CC(C)C)CC(C)C', 'Carbonyls'],
#  ['CC(=CCO)CCC=C(C)C(C)C', 'Alcohol'],
#  ['CC(=CCO)CCCC(C)CCCC(C)CCCC(C)C(C)(C)C', 'Alcohol'],
#  ['CC(=O)C#Cc1ccccc1', 'Carbonyls'],
#  ['CC(=O)C(C(C)=O)C(C)C', 'Carbonyls'],
#  ['CC(=O)C(C(C)=O)C(c1ccccc1)c1ccccc1', 'Carbonyls'],
#  ['CC(=O)C(C(C)=O)C12CC3CC(CC(C3)C1)C2', 'Carbonyls'],
#  ['CC(=O)C(C(C)=O)C1C2CC3CC(C2)CC1C3', 'Carbonyls'],
#  ['CC(=O)C(C)(C(C)=O)C(c1ccccc1)c1ccccc1', 'Carbonyls'],
#  ['CC(=O)C(C)(C(C)=O)C12CC3CC(CC(C3)C1)C2', 'Carbonyls'],
#  ['CC(=O)C(C)(C(C)C)C(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)(C)C(C)(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)(C)C(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)(C)CC(C)(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)(C)O', 'Alcohol'],
#  ['CC(=O)C(C)=C(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)=O', 'Carbonyls'],
#  ['CC(=O)C(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)C(=O)c1ccccc1', 'Carbonyls'],
#  ['CC(=O)C(C)C(C)(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)C(C)=O', 'Carbonyls'],
#  ['CC(=O)C(C)C(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)C(C)O', 'Alcohol'],
#  ['CC(=O)C(C)CC(C)(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)CCCC(C)C', 'Carbonyls'],
#  ['CC(=O)C(C)CO', 'Alcohol'],
#  ['CC(=O)C(C)O', 'Alcohol'],
#  ['CC(=O)C(C)c1ccccc1', 'Carbonyls'],
#  ['CC(=O)C(Cc1ccccc1)C(C)=O', 'Carbonyls'],
#  ['CC(=O)C(Cc1ccccc1)c1ccccc1', 'Carbonyls'],
#  ['CC(=O)C(O)C1CC=CCC1C', 'Alcohol'],
#  ['CC(=O)C(c1c(C)cc(C)cc1C)c1c(C)cc(C)cc1C', 'Carbonyls'],
#  ['CC(=O)C12CC3CC(CC(C3)C1)C2', 'Carbonyls'],
#  ['CC(=O)C1=CCCCC1', 'Carbonyls'],
#  ['CC(=O)C1C(=O)C=C(C)OC1=O', 'Cyclic_Ester'],
#  ['CC(=O)C1CC1', 'Carbonyls'],
#  ['CC(=O)C1CCC1', 'Carbonyls'],
#  ['CC(=O)C1CCCCC1', 'Carbonyls'],
#  ['CC(=O)C1CCCCCC1', 'Carbonyls'],
#  ['CC(=O)C=C(C)C', 'Carbonyls'],
#  ['CC(=O)C=C(C)O', 'Alcohol'],
#  ['CC(=O)C=O', 'Carbonyls'],
#  ['CC(=O)CC(=O)C(C)C', 'Carbonyls'],
#  ['CC(=O)CC(=O)OC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(=O)CC(=O)c1ccccc1', 'Carbonyls'],
#  ['CC(=O)CC(C)(C)C(C)(C)C', 'Carbonyls'],
#  ['CC(=O)CC(C)=O', 'Carbonyls'],
#  ['CC(=O)CC(C)C', 'Carbonyls'],
#  ['CC(=O)CC(C)C(C)(C)C', 'Carbonyls'],
#  ['CC(=O)CC(C)C(C)=O', 'Carbonyls'],
#  ['CC(=O)CC(C)C(C)C', 'Carbonyls'],
#  ['CC(=O)CC(C)CC(C)(C)C', 'Carbonyls'],
#  ['CC(=O)CC(C)CC(C)C', 'Carbonyls'],
#  ['CC(=O)CC(C)CCCC(C)C', 'Carbonyls'],
#  ['CC(=O)CC(C)O', 'Alcohol'],
#  ['CC(=O)CC1CCCCC1', 'Carbonyls'],
#  ['CC(=O)CC=C=C(C)CCC=C(C)C', 'Carbonyls'],
#  ['CC(=O)CCC(C)=O', 'Carbonyls'],
#  ['CC(=O)CCC(C)C', 'Carbonyls'],
#  ['CC(=O)CCC(C)C(C)C', 'Carbonyls'],
#  ['CC(=O)CCC(C)CC(C)(C)C', 'Carbonyls'],
#  ['CC(=O)CCC=C(C)C', 'Carbonyls'],
#  ['CC(=O)CCCC(C)=O', 'Carbonyls'],
#  ['CC(=O)CCCC(C)C', 'Carbonyls'],
#  ['CC(=O)CCCC(C)CCCC(C)C', 'Carbonyls'],
#  ['CC(=O)CCCC(C)CCCC(C)CCCC(C)C', 'Carbonyls'],
#  ['CC(=O)CCCC(C)CCCC(C)CCCC(C)C(C)(C)C', 'Carbonyls'],
#  ['CC(=O)CCCCC(C)C', 'Carbonyls'],
#  ['CC(=O)CCCCCCCCC(C)=O', 'Carbonyls'],
#  ['CC(=O)CCc1ccccc1', 'Carbonyls'],
#  ['CC(=O)Cc1ccc2c(c1)OCO2', 'Cyclic_Ether'],
#  ['CC(=O)Cc1ccccc1', 'Carbonyls'],
#  ['CC(=O)OC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OC(C)(C)C1CC=C(C)CC1', 'Acyclic_Ester'],
#  ['CC(=O)OC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OC(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OC(C)C(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OC(C)CC(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OC(C)OC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OC(OC(C)=O)c1ccccc1', 'Acyclic_Ester'],
#  ['CC(=O)OC(OC(C)=O)c1ccco1', 'Acyclic_Ester'],
#  ['CC(=O)OC1CC(C)CCC1C(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OC1CC2CCC1C2', 'Acyclic_Ester'],
#  ['CC(=O)OC1CCCC1', 'Acyclic_Ester'],
#  ['CC(=O)OC1CCCCC1', 'Acyclic_Ester'],
#  ['CC(=O)OC1CCCCC1C', 'Acyclic_Ester'],
#  ['CC(=O)OC1CCCCC1OC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCC(C(C)C)C(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OCC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OCC(C)OC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCC(O)CO', 'Acyclic_Ester'],
#  ['CC(=O)OCC(O)COC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCC=C(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OCCC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OCCC(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OCCC(C)OC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCCC1(C)OCCO1', 'Acyclic_Ester'],
#  ['CC(=O)OCCCCCCC(C)C', 'Acyclic_Ester'],
#  ['CC(=O)OCCCCOC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCCCOC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCCCc1ccccc1', 'Acyclic_Ester'],
#  ['CC(=O)OCCO', 'Acyclic_Ester'],
#  ['CC(=O)OCCOC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCCOCCOC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCCOCCOCCOC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCCOc1ccc(C(C)(C)C)cc1', 'Acyclic_Ester'],
#  ['CC(=O)OCCOc1ccccc1', 'Acyclic_Ester'],
#  ['CC(=O)OCCc1ccccc1', 'Acyclic_Ester'],
#  ['CC(=O)OCOC(C)=O', 'Acyclic_Ester'],
#  ['CC(=O)OCc1ccccc1', 'Acyclic_Ester'],
#  ['CC(=O)OCc1ccco1', 'Acyclic_Ester'],
#  ['CC(=O)Oc1ccc(C(C)C)cc1', 'Acyclic_Ester'],
#  ['CC(=O)Oc1ccc(C)cc1', 'Acyclic_Ester'],
#  ['CC(=O)Oc1ccc2ccccc2c1', 'Acyclic_Ester'],
#  ['CC(=O)Oc1cccc(C(=O)O)c1', 'Acyclic_Ester'],
#  ['CC(=O)Oc1cccc(C)c1', 'Acyclic_Ester'],
#  ['CC(=O)Oc1cccc2ccccc12', 'Acyclic_Ester'],
#  ['CC(=O)Oc1ccccc1', 'Acyclic_Ester'],
#  ['CC(=O)Oc1ccccc1C(=O)O', 'Acyclic_Ester'],
#  ['CC(=O)c1c(C)cc(C)cc1C', 'Carbonyls'],
#  ['CC(=O)c1c(C)cc(C)cc1O', 'Carbonyls'],
#  ['CC(=O)c1c(C)cccc1C', 'Carbonyls'],
#  ['CC(=O)c1c(O)ccc2ccccc12', 'Carbonyls'],
#  ['CC(=O)c1cc(C)c(C)cc1C', 'Carbonyls'],
#  ['CC(=O)c1cc(C)ccc1C', 'Carbonyls'],
#  ['CC(=O)c1ccc(C(C)C)cc1', 'Carbonyls'],
#  ['CC(=O)c1ccc(C)c(C(C)=O)c1', 'Carbonyls'],
#  ['CC(=O)c1ccc(C)c(C)c1', 'Carbonyls'],
#  ['CC(=O)c1ccc(C)c2ccccc12', 'Carbonyls'],
#  ['CC(=O)c1ccc(C)cc1', 'Carbonyls'],
#  ['CC(=O)c1ccc(C)cc1C', 'Carbonyls'],
#  ['CC(=O)c1ccc(O)c(C)c1', 'Carbonyls'],
#  ['CC(=O)c1ccc(O)cc1', 'Carbonyls'],
#  ['CC(=O)c1ccc2c(c1)OCO2', 'Cyclic_Ether'],
#  ['CC(=O)c1ccc2ccccc2c1', 'Carbonyls'],
#  ['CC(=O)c1ccc2ccccc2c1O', 'Carbonyls'],
#  ['CC(=O)c1cccc(C)c1', 'Carbonyls'],
#  ['CC(=O)c1cccc(O)c1', 'Carbonyls'],
#  ['CC(=O)c1cccc2ccccc12', 'Carbonyls'],
#  ['CC(=O)c1ccccc1', 'Carbonyls'],
#  ['CC(=O)c1ccccc1C', 'Carbonyls'],
#  ['CC(=O)c1ccco1', 'Carbonyls'],
#  ['CC(C(=O)O)C(C)(C)C(=O)O', 'COOH'],
#  ['CC(C(=O)O)C(C)C(=O)O', 'COOH'],
#  ['CC(C(=O)O)c1cccc(C(=O)c2ccccc2)c1', 'COOH'],
#  ['CC(C)(C(=O)O)C(C)(C)C(=O)O', 'COOH'],
#  ['CC(C)(C)C(=O)C(C(=O)C(C)(C)C)C12CC3CC(CC(C3)C1)C2', 'Carbonyls'],
#  ['CC(C)(C)C(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)(C)C(=O)C(C)(C)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)(C)C(=O)C1C(=O)c2ccccc2C1=O', 'Carbonyls'],
#  ['CC(C)(C)C(=O)CC(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)(C)C(=O)OC(=O)C(C)(C)C', 'Acyclic_Ester'],
#  ['CC(C)(C)C(=O)c1ccccc1', 'Carbonyls'],
#  ['CC(C)(C)C(C)(C)O', 'Alcohol'],
#  ['CC(C)(C)C(C)(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)C(CCO)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)C(CO)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)C(O)(C(C)(C)C)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)C(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)C(O)C(O)CO', 'Alcohol'],
#  ['CC(C)(C)C(O)CO', 'Alcohol'],
#  ['CC(C)(C)C(O)c1ccccc1', 'Alcohol'],
#  ['CC(C)(C)C1(O)CCCCCCC1', 'Alcohol'],
#  ['CC(C)(C)C1CCC(=O)C1', 'Carbonyls'],
#  ['CC(C)(C)C1CCC(=O)CC1', 'Carbonyls'],
#  ['CC(C)(C)C1CCC(O)CC1', 'Alcohol'],
#  ['CC(C)(C)C1CCCC(=O)CCC1', 'Carbonyls'],
#  ['CC(C)(C)C1CCCC(O)C1', 'Alcohol'],
#  ['CC(C)(C)C1COCOC1', 'Cyclic_Ether'],
#  ['CC(C)(C)C1OCCCO1', 'Cyclic_Ether'],
#  ['CC(C)(C)C=O', 'Carbonyls'],
#  ['CC(C)(C)CC(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)(C)CC(=O)CC(C)(C)C', 'Carbonyls'],
#  ['CC(C)(C)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)(C)CC(C)(C)c1ccc(O)cc1', 'phenolic'],
#  ['CC(C)(C)CC(C)(C)c1ccccc1O', 'phenolic'],
#  ['CC(C)(C)CC(C)(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)CC(CC(C)(C)C)C(=O)O', 'COOH'],
#  ['CC(C)(C)CC(CO)CC(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)CC(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)CC=O', 'Carbonyls'],
#  ['CC(C)(C)CCC(=O)O', 'COOH'],
#  ['CC(C)(C)CCC(C)(C)CCO', 'Alcohol'],
#  ['CC(C)(C)CCC(C)(C)O', 'Alcohol'],
#  ['CC(C)(C)CCC(CO)CC(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)CCC(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)(C)CCCCCCO', 'Alcohol'],
#  ['CC(C)(C)CCCCCO', 'Alcohol'],
#  ['CC(C)(C)CCCO', 'Alcohol'],
#  ['CC(C)(C)CCO', 'Alcohol'],
#  ['CC(C)(C)CO', 'Alcohol'],
#  ['CC(C)(C)COC(=O)C(C)(C)C', 'Acyclic_Ester'],
#  ['CC(C)(C)O', 'Alcohol'],
#  ['CC(C)(C)OC(=O)C(C)(C)C', 'Acyclic_Ester'],
#  ['CC(C)(C)OC(=O)C1=Cc2c(ccc3ccccc23)OC1C(=O)OC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(C)(C)OC(=O)CC(=O)OC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(C)(C)OC(=O)OC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(C)(C)OC(=O)c1ccccc1', 'Acyclic_Ester'],
#  ['CC(C)(C)OC(C)(C)C', 'Acyclic_Ether'],
#  ['CC(C)(C)OC1CCCCC1', 'Acyclic_Ether'],
#  ['CC(C)(C)OC=O', 'Acyclic_Ester'],
#  ['CC(C)(C)OCC1CO1', 'Acyclic_Ether'],
#  ['CC(C)(C)OCc1ccccc1', 'Acyclic_Ether'],
#  ['CC(C)(C)OO', 'peroxide'],
#  ['CC(C)(C)OOC(=O)c1ccccc1', 'Carbonyls'],
#  ['CC(C)(C)OOC(C)(C)CCC(C)(C)OOC(C)(C)C', 'peroxide'],
#  ['CC(C)(C)OOC(C)(C)c1ccc(C(C)(C)O)cc1', 'Alcohol'],
#  ['CC(C)(C)OOC(C)(C)c1ccc(C(C)(C)OOC(C)(C)C)cc1', 'peroxide'],
#  ['CC(C)(C)OOC(C)(C)c1ccccc1', 'peroxide'],
#  ['CC(C)(C)OOC(O)CO', 'Alcohol'],
#  ['CC(C)(C)OOCC(O)CO', 'Alcohol'],
#  ['CC(C)(C)OOCC1CO1', 'Cyclic_Ether'],
#  ['CC(C)(C)OOCCO', 'Alcohol'],
#  ['CC(C)(C)OOCO', 'Alcohol'],
#  ['CC(C)(C)Oc1ccc(C(C)(C)C)cc1', 'Acyclic_Ether'],
#  ['CC(C)(C)Oc1ccccc1', 'Acyclic_Ether'],
#  ['CC(C)(C)c1cc(C(=O)O)cc(C(C)(C)C)c1', 'COOH'],
#  ['CC(C)(C)c1cc(C(C)(C)C)c(O)c(C(C)(C)C)c1', 'phenolic'],
#  ['CC(C)(C)c1cc(Cc2cc(C(C)(C)C)c(O)c(C(C)(C)C)c2)cc(C(C)(C)C)c1O', 'phenolic'],
#  ['CC(C)(C)c1cc(O)c(O)c(C(C)(C)C)c1', 'phenolic'],
#  ['CC(C)(C)c1cc(O)cc(C(C)(C)C)c1', 'phenolic'],
#  ['CC(C)(C)c1ccc(C(=O)c2ccccc2)cc1', 'Carbonyls'],
#  ['CC(C)(C)c1ccc(C(C)(C)C)o1', 'Furanics'],
#  ['CC(C)(C)c1ccc(O)c(O)c1', 'phenolic'],
#  ['CC(C)(C)c1ccc(OC(=O)c2ccccc2O)cc1', 'Acyclic_Ester'],
#  ['CC(C)(C)c1cccc(C(=O)O)c1', 'COOH'],
#  ['CC(C)(C)c1cccc(C(C)(C)C)c1O', 'phenolic'],
#  ['CC(C)(C)c1cccc(O)c1', 'phenolic'],
#  ['CC(C)(C)c1ccccc1C(=O)O', 'COOH'],
#  ['CC(C)(C)c1ccccc1O', 'phenolic'],
#  ['CC(C)(C)c1ccco1', 'Furanics'],
#  ['CC(C)(CC(=O)O)C(=O)O', 'COOH'],
#  ['CC(C)(CC(=O)O)CC(=O)O', 'COOH'],
#  ['CC(C)(CCC(=O)O)C(=O)O', 'COOH'],
#  ['CC(C)(CCO)CCO', 'Alcohol'],
#  ['CC(C)(CO)CCO', 'Alcohol'],
#  ['CC(C)(O)C#CC(C)(C)O', 'Alcohol'],
#  ['CC(C)(O)C#CCO', 'Alcohol'],
#  ['CC(C)(O)C(C)(C)C(C)(C)O', 'Alcohol'],
#  ['CC(C)(O)C1CCC1', 'Alcohol'],
#  ['CC(C)(O)C1CCCC1', 'Alcohol'],
#  ['CC(C)(O)C1CCCCC1', 'Alcohol'],
#  ['CC(C)(O)C=CCCO', 'Alcohol'],
#  ['CC(C)(O)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)(O)CCC(C)(C)O', 'Alcohol'],
#  ['CC(C)(O)CCC(C)(C)OOC(C)(C)C', 'Alcohol'],
#  ['CC(C)(O)CCCC(C)(C)O', 'Alcohol'],
#  ['CC(C)(O)CCCCCCC(C)(C)O', 'Alcohol'],
#  ['CC(C)(O)CCCCCCCC(C)(C)O', 'Alcohol'],
#  ['CC(C)(O)CCCCCCO', 'Alcohol'],
#  ['CC(C)(O)CCCCCO', 'Alcohol'],
#  ['CC(C)(O)CCCCO', 'Alcohol'],
#  ['CC(C)(O)CCCCc1ccccc1', 'Alcohol'],
#  ['CC(C)(O)CCCO', 'Alcohol'],
#  ['CC(C)(O)CCO', 'Alcohol'],
#  ['CC(C)(O)CCc1ccccc1', 'Alcohol'],
#  ['CC(C)(O)CO', 'Alcohol'],
#  ['CC(C)(O)Cc1ccccc1', 'Alcohol'],
#  ['CC(C)(O)c1ccc(C(C)(C)O)cc1', 'Alcohol'],
#  ['CC(C)(OO)c1ccccc1', 'peroxide'],
#  ['CC(C)(OOC(=O)c1ccccc1)c1ccccc1', 'Carbonyls'],
#  ['CC(C)(c1ccc(O)cc1)c1ccc(O)cc1', 'phenolic'],
#  ['CC(C)(c1ccc(OCC2CO2)cc1)c1ccc(OCC2CO2)cc1', 'Acyclic_Ether'],
#  ['CC(C)(c1ccccc1)c1ccc(O)cc1', 'phenolic'],
#  ['CC(C)=C(C)OC(C)C', 'Acyclic_Ether'],
#  ['CC(C)=C(C)OCC(C)(C)C', 'Acyclic_Ether'],
#  ['CC(C)=CC(=O)C(=O)C=C(C)C', 'Carbonyls'],
#  ['CC(C)=CC(=O)C=C(C)C', 'Carbonyls'],
#  ['CC(C)=CC1C(C(=O)O)C1(C)C', 'COOH'],
#  ['CC(C)=CC1C(C(=O)OCc2coc(Cc3ccccc3)c2)C1(C)C', 'Acyclic_Ester'],
#  ['CC(C)=CCCC(C)CC=O', 'Carbonyls'],
#  ['CC(C)=CCCC(C)CCO', 'Alcohol'],
#  ['CC(C)=CCCC(C)O', 'Alcohol'],
#  ['CC(C)=CCO', 'Alcohol'],
#  ['CC(C)=CCOCC=C(C)C', 'Acyclic_Ether'],
#  ['CC(C)=COCC(C)C', 'Acyclic_Ether'],
#  ['CC(C)=O', 'Carbonyls'],
#  ['CC(C)C#CC(O)C(C)C', 'Alcohol'],
#  ['CC(C)C(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)C(=O)C(C)(C)C(C)C', 'Carbonyls'],
#  ['CC(C)C(=O)C(C)C', 'Carbonyls'],
#  ['CC(C)C(=O)CC(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)C(=O)CC(=O)C(C)C', 'Carbonyls'],
#  ['CC(C)C(=O)CCCCC(=O)C(C)C', 'Carbonyls'],
#  ['CC(C)C(=O)CO', 'Alcohol'],
#  ['CC(C)C(=O)c1ccccc1', 'Carbonyls'],
#  ['CC(C)C(C)(C(C)C)C(C)O', 'Alcohol'],
#  ['CC(C)C(C)(C)C(C)(C)O', 'Alcohol'],
#  ['CC(C)C(C)(C)C(C)O', 'Alcohol'],
#  ['CC(C)C(C)(C)CO', 'Alcohol'],
#  ['CC(C)C(C)(C)c1ccc(O)cc1', 'phenolic'],
#  ['CC(C)C(C)(CO)CO', 'Alcohol'],
#  ['CC(C)C(C)(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)C(C)(O)C(C)(C)C(C)(C)C', 'Alcohol'],
#  ['CC(C)C(C)(O)CC(C)(C)C', 'Alcohol'],
#  ['CC(C)C(C)(O)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)C(C)(O)CO', 'Alcohol'],
#  ['CC(C)C(C)(O)c1ccccc1', 'Alcohol'],
#  ['CC(C)C(C)C(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)C(C)C(C)(C)O', 'Alcohol'],
#  ['CC(C)C(C)C(C)C(=O)O', 'COOH'],
#  ['CC(C)C(C)C(C)CO', 'Alcohol'],
#  ['CC(C)C(C)C(C)O', 'Alcohol'],
#  ['CC(C)C(C)C=O', 'Carbonyls'],
#  ['CC(C)C(C)CC(=O)O', 'COOH'],
#  ['CC(C)C(C)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)C(C)CC=C(C=O)C(C)C(C)C', 'Carbonyls'],
#  ['CC(C)C(C)CC=O', 'Carbonyls'],
#  ['CC(C)C(C)CCC(=O)O', 'COOH'],
#  ['CC(C)C(C)CCC(C)(C)O', 'Alcohol'],
#  ['CC(C)C(C)CCO', 'Alcohol'],
#  ['CC(C)C(C)CO', 'Alcohol'],
#  ['CC(C)C(C)O', 'Alcohol'],
#  ['CC(C)C(CCO)C(C)(C)C', 'Alcohol'],
#  ['CC(C)C(CO)C(C)C', 'Alcohol'],
#  ['CC(C)C(CO)CCCO', 'Alcohol'],
#  ['CC(C)C(CO)CCO', 'Alcohol'],
#  ['CC(C)C(CO)CO', 'Alcohol'],
#  ['CC(C)C(O)(C(C)C)C(C)(C)C', 'Alcohol'],
#  ['CC(C)C(O)(C(C)C)C(C)C', 'Alcohol'],
#  ['CC(C)C(O)(CC(=O)O)c1ccccc1', 'COOH'],
#  ['CC(C)C(O)C(C)(C)C(C)C', 'Alcohol'],
#  ['CC(C)C(O)C(C)(C)CO', 'Alcohol'],
#  ['CC(C)C(O)C(C)C', 'Alcohol'],
#  ['CC(C)C(O)CC(C)(C)C', 'Alcohol'],
#  ['CC(C)C(O)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)C1(C(C)C)OCCO1', 'Cyclic_Ether'],
#  ['CC(C)C1(C)CCCO1', 'Cyclic_Ether'],
#  ['CC(C)C1(C)OCCO1', 'Cyclic_Ether'],
#  ['CC(C)C1(O)CCCCC1', 'Alcohol'],
#  ['CC(C)C1=CC(=O)C(C)CC1', 'Carbonyls'],
#  ['CC(C)C1CCC(C)(C(=O)O)C1', 'COOH'],
#  ['CC(C)C1CCC(O)CC1', 'Alcohol'],
#  ['CC(C)C1CO1', 'Cyclic_Ether'],
#  ['CC(C)C1OCC(CO)CO1', 'Cyclic_Ether'],
#  ['CC(C)C1OCCCO1', 'Cyclic_Ether'],
#  ['CC(C)C=CC(=O)C(C)C', 'Carbonyls'],
#  ['CC(C)C=CC(=O)CC(C)C', 'Carbonyls'],
#  ['CC(C)C=O', 'Carbonyls'],
#  ['CC(C)CC(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(C)CC(=O)C(C)C', 'Carbonyls'],
#  ['CC(C)CC(=O)CC(C)(C)C', 'Carbonyls'],
#  ['CC(C)CC(=O)CC(C)CC(C)C', 'Carbonyls'],
#  ['CC(C)CC(=O)O', 'COOH'],
#  ['CC(C)CC(=O)OC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CC(=O)c1ccccc1', 'Carbonyls'],
#  ['CC(C)CC(C)(C)CC(=O)O', 'COOH'],
#  ['CC(C)CC(C)(C)CCO', 'Alcohol'],
#  ['CC(C)CC(C)(C)CO', 'Alcohol'],
#  ['CC(C)CC(C)(C)COC(=O)C(C)C', 'Acyclic_Ester'],
#  ['CC(C)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)CC(C)(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)CC(C)(O)C(C)C', 'Alcohol'],
#  ['CC(C)CC(C)(O)CC(C)(C)C', 'Alcohol'],
#  ['CC(C)CC(C)(O)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)CC(C)(OOC(C)(C)C)OOC(C)(C)C', 'peroxide'],
#  ['CC(C)CC(C)C(=O)O', 'COOH'],
#  ['CC(C)CC(C)C(C)O', 'Alcohol'],
#  ['CC(C)CC(C)CC(=O)O', 'COOH'],
#  ['CC(C)CC(C)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)CC(C)CC(O)CC(C)C', 'Alcohol'],
#  ['CC(C)CC(C)CCCO', 'Alcohol'],
#  ['CC(C)CC(C)CCO', 'Alcohol'],
#  ['CC(C)CC(C)O', 'Alcohol'],
#  ['CC(C)CC(CO)C(C)C', 'Alcohol'],
#  ['CC(C)CC(CO)CC(C)C', 'Alcohol'],
#  ['CC(C)CC(CO)CCCO', 'Alcohol'],
#  ['CC(C)CC(O)(C(C)(C)C)C(C)(C)C', 'Alcohol'],
#  ['CC(C)CC(O)(C(C)C)C(C)C', 'Alcohol'],
#  ['CC(C)CC(O)(CC(C)C)C(C)C', 'Alcohol'],
#  ['CC(C)CC(O)(CC(C)C)CC(C)C', 'Alcohol'],
#  ['CC(C)CC(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)CC(O)C(C)C', 'Alcohol'],
#  ['CC(C)CC(O)CC(C)(C)C', 'Alcohol'],
#  ['CC(C)CC(O)CC(C)(C)O', 'Alcohol'],
#  ['CC(C)CC(O)CC(C)C', 'Alcohol'],
#  ['CC(C)CC(O)CC(C)O', 'Alcohol'],
#  ['CC(C)CC1CCCO1', 'Cyclic_Ether'],
#  ['CC(C)CC=O', 'Carbonyls'],
#  ['CC(C)CCC(=O)C(C)C', 'Carbonyls'],
#  ['CC(C)CCC(=O)CC(C)C', 'Carbonyls'],
#  ['CC(C)CCC(=O)CCC(C)C', 'Carbonyls'],
#  ['CC(C)CCC(C)(C)CC=O', 'Carbonyls'],
#  ['CC(C)CCC(C)(C)c1ccc(O)cc1', 'phenolic'],
#  ['CC(C)CCC(C)(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)CCC(C)(O)C(C)C', 'Alcohol'],
#  ['CC(C)CCC(C)(O)CC(C)C', 'Alcohol'],
#  ['CC(C)CCC(C)(O)CCC(C)C', 'Alcohol'],
#  ['CC(C)CCC(C)C(=O)O', 'COOH'],
#  ['CC(C)CCC(C)C(C)(C)O', 'Alcohol'],
#  ['CC(C)CCC(C)CC(=O)O', 'COOH'],
#  ['CC(C)CCC(C)CCCO', 'Alcohol'],
#  ['CC(C)CCC(C)CCO', 'Alcohol'],
#  ['CC(C)CCC(C)CO', 'Alcohol'],
#  ['CC(C)CCC(CO)C(C)C', 'Alcohol'],
#  ['CC(C)CCC(O)(C(C)C)C(C)C', 'Alcohol'],
#  ['CC(C)CCC(O)C(C)(C)C', 'Alcohol'],
#  ['CC(C)CCC(O)C(C)C', 'Alcohol'],
#  ['CC(C)CCC(O)CC(C)C', 'Alcohol'],
#  ['CC(C)CCC1(C)CCCO1', 'Cyclic_Ether'],
#  ['CC(C)CCC1(O)CCCCC1', 'Alcohol'],
#  ['CC(C)CCC=O', 'Carbonyls'],
#  ['CC(C)CCCC(=O)O', 'COOH'],
#  ['CC(C)CCCC(C)(C)O', 'Alcohol'],
#  ['CC(C)CCCC(C)(O)CCO', 'Alcohol'],
#  ['CC(C)CCCC(C)C(=O)O', 'COOH'],
#  ['CC(C)CCCC(C)C(C)CCO', 'Alcohol'],
#  ['CC(C)CCCC(C)C(C)O', 'Alcohol'],
#  ['CC(C)CCCC(C)CC(=O)O', 'COOH'],
#  ['CC(C)CCCC(C)CC=O', 'Carbonyls'],
#  ['CC(C)CCCC(C)CCC(=O)O', 'COOH'],
#  ['CC(C)CCCC(C)CCC=O', 'Carbonyls'],
#  ['CC(C)CCCC(C)CCCC(C)CCCC(C)O', 'Alcohol'],
#  ['CC(C)CCCC(C)CCCO', 'Alcohol'],
#  ['CC(C)CCCC(C)O', 'Alcohol'],
#  ['CC(C)CCCC(O)C(C)C', 'Alcohol'],
#  ['CC(C)CCCC=O', 'Carbonyls'],
#  ['CC(C)CCCCC(C)(C)O', 'Alcohol'],
#  ['CC(C)CCCCC(C)CO', 'Alcohol'],
#  ['CC(C)CCCCC(C)O', 'Alcohol'],
#  ['CC(C)CCCCCC(C)O', 'Alcohol'],
#  ['CC(C)CCCCCC=O', 'Carbonyls'],
#  ['CC(C)CCCCCCCCC(=O)O', 'COOH'],
#  ['CC(C)CCCCCCCCCCC(=O)O', 'COOH'],
#  ['CC(C)CCCCCCCCCCCCC(=O)O', 'COOH'],
#  ['CC(C)CCCCCCCCCCCCCCC(=O)O', 'COOH'],
#  ['CC(C)CCCCCCCCCCCCCCCCC(=O)O', 'COOH'],
#  ['CC(C)CCCCCCCCCCCCCCCO', 'Alcohol'],
#  ['CC(C)CCCCCCCCCCCCCO', 'Alcohol'],
#  ['CC(C)CCCCCCCCCCCO', 'Alcohol'],
#  ['CC(C)CCCCCCCCCO', 'Alcohol'],
#  ['CC(C)CCCCCCCO', 'Alcohol'],
#  ['CC(C)CCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCCCCCO', 'Alcohol'],
#  ['CC(C)CCCCCO', 'Alcohol'],
#  ['CC(C)CCCCO', 'Alcohol'],
#  ['CC(C)CCCCOC(=O)c1ccccc1C(=O)OCCCCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCCO', 'Alcohol'],
#  ['CC(C)CCO', 'Alcohol'],
#  ['CC(C)CCOC(=O)C(=O)OCCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)C(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)CC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)CCC(=O)OCCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)CCCC(=O)OCCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)OCCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)c1ccccc1', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)c1ccccc1C(=O)OCCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)CCOC(=O)c1ccccc1O', 'Acyclic_Ester'],
#  ['CC(C)CCOC(C)(C)C', 'Acyclic_Ether'],
#  ['CC(C)CCOC(C)C', 'Acyclic_Ether'],
#  ['CC(C)CCOC=O', 'Acyclic_Ester'],
#  ['CC(C)CCOCC(C)C', 'Acyclic_Ether'],
#  ['CC(C)CCOCC(O)CO', 'Acyclic_Ether'],
#  ['CC(C)CCOCC1CO1', 'Acyclic_Ether'],
#  ['CC(C)CCOCCC(C)C', 'Acyclic_Ether'],
#  ['CC(C)CCc1ccc(O)cc1', 'phenolic'],
#  ['CC(C)COC(=O)C(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)C1CCCCC1C(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)CC(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)CCC(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)CCCCC(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)CCCCCCCC(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)c1ccc(C(=O)OCC(C)C)cc1', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)c1cccc(C(=O)OCC(C)C)c1', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)c1ccccc1', 'Acyclic_Ester'],
#  ['CC(C)COC(=O)c1ccccc1C(=O)OCC(C)C', 'Acyclic_Ester'],
#  ['CC(C)COC(C)(C)C', 'Acyclic_Ether'],
#  ['CC(C)COC(C)C', 'Acyclic_Ether'],
#  ['CC(C)COC(C)OCC(C)C', 'Acyclic_Ether'],
#  ['CC(C)COC=O', 'Acyclic_Ester'],
#  ['CC(C)COCC(C)C', 'Acyclic_Ether'],
#  ['CC(C)COCC1CO1', 'Acyclic_Ether'],
#  ['CC(C)COCCO', 'Acyclic_Ether'],
#  ['CC(C)COCOCC(C)C', 'Acyclic_Ether'],
#  ['CC(C)COc1ccccc1', 'Acyclic_Ether'],
#  ['CC(C)Cc1ccc(C(C)C(=O)O)cc1', 'COOH'],
#  ['CC(C)Cc1ccc(O)cc1', 'phenolic'],
#  ['CC(C)Cc1cccc(CC(C)C)c1O', 'phenolic'],
#  ['CC(C)Cc1cccc(O)c1', 'phenolic'],
#  ['CC(C)Cc1ccccc1O', 'phenolic'],
#  ['CC(C)Cc1ccco1', 'Furanics'],
#  ['CC(C)O', 'Alcohol'],
#  ['CC(C)OC(=O)C(=O)OC(C)C', 'Acyclic_Ester'],
#  ['CC(C)OC(=O)C(C)(C)C', 'Acyclic_Ester'],
#  ['CC(C)OC(=O)C(C)C', 'Acyclic_Ester'],
#  ['CC(C)OC(=O)CCC(=O)OC(C)C', 'Acyclic_Ester'],
#  ['CC(C)OC(=O)CCCC(=O)OC(C)C', 'Acyclic_Ester'],
#  ['CC(C)OC(=O)c1ccccc1', 'Acyclic_Ester'],
#  ['CC(C)OC(=O)c1ccccc1C(=O)OC(C)C', 'Acyclic_Ester'],
#  ['CC(C)OC(C)(C)C', 'Acyclic_Ether'],
#  ['CC(C)OC(C)C', 'Acyclic_Ether'],
#  ['CC(C)OC(C)OC(C)C', 'Acyclic_Ether'],
#  ['CC(C)OC(C)c1ccccc1', 'Acyclic_Ether'],
#  ['CC(C)OC(OC(C)C)C(C)C', 'Acyclic_Ether'],
#  ['CC(C)OC1=CC=CCC1', 'Acyclic_Ether'],
#  ['CC(C)OC1=CCC=CC1', 'Acyclic_Ether'],
#  ['CC(C)OC1=CCCC=C1', 'Acyclic_Ether'],
#  ['CC(C)OC=O', 'Acyclic_Ester'],
#  ['CC(C)OCC1CO1', 'Acyclic_Ether'],
#  ['CC(C)OCCO', 'Acyclic_Ether'],
#  ['CC(C)OCCOCCO', 'Acyclic_Ether'],
#  ['CC(C)OCc1ccccc1', 'Acyclic_Ether'],
#  ['CC(C)Oc1ccccc1', 'Acyclic_Ether'],
#  ['CC(C)c1cc(C(C)C)c(C(=O)c2ccccc2)c(C(C)C)c1', 'Carbonyls'],
#  ['CC(C)c1cc(C(C)C)c(O)c(C(C)C)c1', 'phenolic'],
#  ['CC(C)c1cc(C(C)C)cc(C2(O)C3=CC=C3C=CC2(C)C)c1', 'Alcohol'],
#  ['CC(C)c1cc(O)cc(C(C)C)c1', 'phenolic'],
#  ['CC(C)c1ccc(C(=O)O)cc1', 'COOH'],
#  ['CC(C)c1ccc(C(=O)c2ccccc2)cc1', 'Carbonyls'],
#  ['CC(C)c1ccc(C(C)(C)O)cc1', 'Alcohol'],
#  ['CC(C)c1ccc(C(C)(C)OOC(C)(C)C)cc1', 'peroxide'],
#  ['CC(C)c1ccc(C(C)C)c(O)c1', 'phenolic'],
#  ['CC(C)c1ccc(C=O)cc1', 'Carbonyls'],
#  ['CC(C)c1ccc(CO)cc1', 'Alcohol'],
#  ['CC(C)c1ccc(O)c(C(C)C)c1', 'phenolic'],
#  ['CC(C)c1ccc(O)cc1', 'phenolic'],
#  ['CC(C)c1ccc2occ(C=O)c(=O)c2c1', 'Carbonyls'],
#  ['CC(C)c1cccc(C(=O)O)c1', 'COOH'],
#  ['CC(C)c1cccc(O)c(=O)c1', 'Carbonyls'],
#  ['CC(C)c1cccc(O)c1O', 'phenolic'],
#  ['CC(C)c1ccccc1C(=O)O', 'COOH'],
#  ['CC(C)c1ccccc1O', 'phenolic'],
#  ['CC(C=O)=Cc1ccccc1', 'Carbonyls'],
#  ['CC(C=O)CC(C)C(C)C', 'Carbonyls'],
#  ['CC(C=O)Cc1ccc(C(C)C)cc1', 'Carbonyls'],
#  ['CC(C=O)c1ccccc1', 'Carbonyls'],
#  ['CC(CC(=O)O)C(=O)O', 'COOH'],
#  ['CC(CC(=O)O)C(C)(C)C', 'COOH'],
#  ['CC(CC(=O)O)C(C)CC(=O)O', 'COOH'],
#  ['CC(CC(C)(C)C)C(=O)C(C)(C)C', 'Carbonyls'],
#  ['CC(CC(C)(C)C)C(=O)O', 'COOH'],
#  ['CC(CC(C)(C)C)C(O)C(C)(C)C', 'Alcohol'],
#  ['CC(CC=CC(=O)O)CC(C)(C)C', 'COOH'],
#  ['CC(CC=O)CC(C)(C)C', 'Carbonyls'],
#  ['CC(CCCC(=O)O)C(=O)O', 'COOH'],
#  ['CC(CCO)C(C)(C)O', 'Alcohol'],
#  ['CC(CCO)CC(C)(C)C', 'Alcohol'],
#  ['CC(CCO)CCC(O)C(C)C', 'Alcohol'],
#  ['CC(CCO)CCCC(C)(C)O', 'Alcohol'],
#  ['CC(CCO)CCCO', 'Alcohol'],
#  ['CC(CCO)CCO', 'Alcohol'],
#  ['CC(CCO)c1ccccc1', 'Alcohol'],
#  ['CC(CO)(CO)C1CCCC1', 'Alcohol'],
#  ['CC(CO)(CO)C1CCCCC1', 'Alcohol'],
#  ['CC(CO)(CO)CO', 'Alcohol'],
#  ['CC(CO)(CO)Cc1ccccc1', 'Alcohol'],
#  ['CC(CO)(c1ccccc1)c1ccccc1', 'Alcohol'],
#  ['CC(CO)=C(C)CCO', 'Alcohol'],
#  ['CC(CO)C(C)(C)C', 'Alcohol'],
#  ['CC(CO)C(C)CO', 'Alcohol'],
#  ['CC(CO)CC(C)(C)C', 'Alcohol'],
#  ['CC(CO)CC(C)CO', 'Alcohol'],
#  ['CC(CO)CCCO', 'Alcohol'],
#  ['CC(CO)CCO', 'Alcohol'],
#  ['CC(CO)CO', 'Alcohol'],
#  ['CC(CO)c1ccccc1', 'Alcohol'],
#  ['CC(O)(c1ccccc1)c1ccccc1', 'Alcohol'],
#  ['CC(O)=CC(=O)OC(C)(C)C', 'Acyclic_Ester'],
#  ['CC(O)C#CCO', 'Alcohol'],
#  ['CC(O)C(C)(C)C', 'Alcohol'],
#  ['CC(O)C(C)(C)C(C)(C)C', 'Alcohol'],
#  ['CC(O)C(C)(C)CC(C)(C)C', 'Alcohol'],
#  ['CC(O)C(C)(C)CO', 'Alcohol'],
#  ['CC(O)C(C)(O)C(C)O', 'Alcohol'],
#  ['CC(O)C(C)(c1ccccc1)c1ccccc1', 'Alcohol'],
#  ['CC(O)C(C)C(C)(C)C', 'Alcohol'],
#  ['CC(O)C(C)C(C)O', 'Alcohol'],
#  ['CC(O)C(C)CCCCCO', 'Alcohol'],
#  ['CC(O)C(C)CCCO', 'Alcohol'],
#  ['CC(O)C(C)CCO', 'Alcohol'],
#  ['CC(O)C(C)CO', 'Alcohol'],
#  ['CC(O)C(C)O', 'Alcohol'],
#  ['CC(O)C(C)c1ccccc1', 'Alcohol'],
#  ['CC(O)C(O)C(C)O', 'Alcohol'],
#  ['CC(O)C(O)CO', 'Alcohol'],
#  ['CC(O)C1(C)CC=CCC1', 'Alcohol'],
#  ['CC(O)C1(C)CCCCC1', 'Alcohol'],
#  ['CC(O)C12CCC(CC1)C2', 'Alcohol'],
#  ['CC(O)C1=CCCCC1', 'Alcohol'],
#  ['CC(O)C1CC1', 'Alcohol'],
#  ['CC(O)C=CCC(C)C', 'Alcohol'],
#  ['CC(O)CC(=O)C(C)C', 'Alcohol'],
#  ['CC(O)CC(C)(C)C', 'Alcohol'],
#  ['CC(O)CC(C)(C)O', 'Alcohol'],
#  ['CC(O)CC(C)CC(C)(C)C', 'Alcohol'],
#  ['CC(O)CC(C)CC(C)(C)O', 'Alcohol'],
#  ['CC(O)CC1CCCCC1', 'Alcohol'],
#  ['CC(O)CC=O', 'Alcohol'],
#  ['CC(O)CCC(C)(C)C', 'Alcohol'],
#  ['CC(O)CCC(C)C(C)C', 'Alcohol'],
#  ['CC(O)CCC(C)O', 'Alcohol'],
#  ['CC(O)CCC(C)OCCC1CCCCC1', 'Acyclic_Ether'],
#  ['CC(O)CCCC(C)O', 'Alcohol'],
#  ['CC(O)CCCCCCO', 'Alcohol'],
#  ['CC(O)CCCCCO', 'Alcohol'],
#  ['CC(O)CCCCO', 'Alcohol'],
#  ['CC(O)CCO', 'Alcohol'],
#  ['CC(O)CO', 'Alcohol'],
#  ['CC(O)COC(C)(C)C', 'Acyclic_Ether'],
#  ['CC(O)COC(C)CO', 'Acyclic_Ether'],
#  ['CC(O)COC(C)COC(C)COC(C)COC(C)C', 'Acyclic_Ether'],
#  ['CC(O)COCC(C)O', 'Acyclic_Ether'],
#  ['CC(O)COc1ccccc1', 'Acyclic_Ether'],
#  ['CC(O)O', 'Alcohol'],
#  ['CC(O)c1cccc(C(C)(C)C)c1', 'Alcohol'],
#  ['CC(O)c1ccccc1', 'Alcohol'],
#  ['CC(O)c1ccco1', 'Alcohol'],
#  ['CC(OC(C)c1ccccc1)c1ccccc1', 'Acyclic_Ether'],
#  ['CC(OC1CCCCC1)c1ccccc1', 'Acyclic_Ether'],
#  ['CC(OCCCCCCOC(C)C1CCCCC1)C1CCCCC1', 'Acyclic_Ether'],
#  ['CC(c1ccccc1)C(CO)c1ccccc1', 'Alcohol'],
#  ['CC1(C(=O)O)CCCCC1', 'COOH'],
#  ['CC1(C(c2ccccc2)c2ccccc2)C(=O)CCC1=O', 'Carbonyls'],
#  ['CC1(C(c2ccccc2)c2ccccc2)C(=O)CCCC1=O', 'Carbonyls'],
#  ['CC1(C)C(=O)C(C)(C)C1=O', 'Carbonyls'],
#  ['CC1(C)C(=O)OC(=O)C1(C)C', 'Cyclic_Ester'],
#  ['CC1(C)C(=O)OC12CCCCC2', 'Cyclic_Ester'],
#  ['CC1(C)C2CCC1(C)C(O)C2', 'Alcohol'],
#  ['CC1(C)CC(=O)CC(=O)C1', 'Carbonyls'],
#  ...]

# %%
pd.DataFrame(result).to_csv('functional_groups.csv',index=False, header = ['smiles','functional_group'])

# %%
for x in result:
    smi, fg = x
    df.loc[(df.smiles == smi), 'functional_group'] = fg

# %%
import numpy as np
df['AE'] = np.abs(df.NIST - df.Predicted)

# %%
df
# Out:
#         Unnamed: 0  Predicted      NIST  temperature Train/Valid/Test  \
# 0           137734  87.557960   6.61901     150.0000             Test
# 1           137736  90.610910   8.73150      90.6941             Test
# 2           137735  89.892750   8.51043     100.0000             Test
# 3           137737  10.509477   8.15453     290.0000             Test
# 4           137738  10.837637  11.63790     260.0000             Test
# ...            ...        ...       ...          ...              ...
# 153100      124098  14.387741  14.57940     640.0000            Train
# 153101      124099  51.890213  52.88470     300.0000            Train
# 153102      124078  43.905960  43.99980     420.0000            Train
# 153103      124091  28.163960  27.73100     580.0000            Train
# 153104      124080  46.577553  47.12810     380.0000            Train
#
#                    smiles     ML_unc    DB_unc  sample_weight  total_atoms  \
# 0                       C  22.069708  0.076146            1.0            1
# 1                       C  23.045454  0.436585            1.0            1
# 2                       C  22.790491  0.254270            1.0            1
# 3                     C#C   6.288347  0.292922            1.0            2
# 4                     C#C   6.702164  0.151327            1.0            2
# ...                   ...        ...       ...            ...          ...
# 153100  c1coc(Cc2ccco2)c1   7.405857  5.580340            1.0           11
# 153101  c1coc(Cc2ccco2)c1   5.720401  3.761330            1.0           11
# 153102  c1coc(Cc2ccco2)c1   3.145880  2.231770            1.0           11
# 153103  c1coc(Cc2ccco2)c1   2.680500  1.724390            1.0           11
# 153104  c1coc(Cc2ccco2)c1   3.456097  2.481370            1.0           11
#
#        functional_group         AE
# 0                Alkane  80.938950
# 1                Alkane  81.879410
# 2                Alkane  81.382320
# 3                Alkyne   2.354947
# 4                Alkyne   0.800263
# ...                 ...        ...
# 153100         Furanics   0.191659
# 153101         Furanics   0.994487
# 153102         Furanics   0.093840
# 153103         Furanics   0.432960
# 153104         Furanics   0.550547
#
# [153105 rows x 12 columns]

# %%
for fg, sub_df in df.groupby('functional_group'):
    #for dataset, subsub_df in sub_df.groupby('Train/Valid/Test'):
    print(fg, len(sub_df.smiles.unique()), len(sub_df), sub_df.AE.mean())
# Out:
# Acyclic_Ester 983 20757 3.0653690221333525
# Acyclic_Ether 676 14428 3.04671788970682
# Alcohol 1106 24134 3.6913712314266176
# Alkane 454 9708 2.24479844894726
# Alkene 1083 22975 2.499672108576279
# Alkyne 153 3350 2.655587697653731
# Aromatics 541 10384 3.7960682203996527
# COOH 285 5922 6.013156185449172
# Carbonyls 647 13450 3.7767016291933087
# Cyclic_Ester 61 1175 4.155512105702128
# Cyclic_Ether 208 4486 5.086286242287115
# Cycloalkanes 335 6724 5.262001734318857
# Furanics 35 706 2.240608812747875
# FusedRing-Aromatics 445 7271 4.984113923091734
# FusedRing-Cycloalkanes 142 2741 5.1613859951112735
# peroxide 30 652 4.572918860490798
# phenolic 214 4233 3.7020053000708715
# water or carbon monoxide 2 9 4.436921000000001

# %%
len(df.functional_group.unique())
# Out:
# 18

# %%
'.'.join([x[0] for x in result if x[1] == 'Acyclic_Ether' and '=O' in x[0]])
# Out:
# 'C=C(C)C1Cc2c(ccc3c2OC2COc4cc(OC)c(OC)cc4C2C3=O)O1.C=C(OC)C(C)C(C)=O.C=CCOc1ccc(O)c2c1C(=O)c1ccccc1C2=O.C=CCOc1cccc2c1C(=O)c1c(OCC=C)cccc1C2=O.C=COc1ccc(C(C)=O)cc1.CCCCCCCCCCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCCOc1ccc(C(=O)O)cc1.CCCCCCOc1ccc(C(=O)O)cc1.CCCCCOc1ccc(C(=O)O)cc1.CCCCOC(C)C(=O)O.CCCCOc1ccc(C(=O)O)cc1.CCCOc1ccc(C(=O)O)cc1.CCOc1c(OCC)c(=O)c1=O.CCOc1cc(C=O)ccc1O.CCOc1ccc(CC(=O)O)cc1.CCOc1cccc(C=O)c1O.COC(OC)(C(=O)c1ccccc1)c1ccccc1.COCC(=O)c1ccccc1.COCC(C)=O.COCC=O.COc1c2c(cc3ccccc13)C(=O)C=CC2=O.COc1cc(C(=O)O)cc(OC)c1O.COc1cc(C(=O)O)cc(OC)c1OC.COc1cc(C(=O)O)ccc1O.COc1cc(C)cc(C)c1C(C)=O.COc1cc(CC(=O)O)cc(OC)c1OC.COc1cc(OC)c(C(=O)O)cc1OC.COc1cc(OC)c(C=O)c(OC)c1.COc1cc(OC)c(OC)cc1C=O.COc1cc(OC)cc(C(=O)O)c1.COc1ccc(C(=O)C(O)c2ccc(OC)cc2)cc1.COc1ccc(C(=O)O)c(OC)c1.COc1ccc(C(=O)O)cc1.COc1ccc(C(=O)O)cc1OC.COc1ccc(C(=O)c2ccc(OC)cc2O)c(O)c1.COc1ccc(C(=O)c2ccccc2)c(O)c1.COc1ccc(C(=O)c2ccccc2O)c(O)c1.COc1ccc(C(C)=O)cc1.COc1ccc(C=O)c(OC)c1OC.COc1ccc(C=O)cc1O.COc1ccc(CC(=O)O)cc1.COc1ccc(CCCC(=O)O)cc1.COc1ccc2c(c1)C(=O)CCC2.COc1ccc2c(c1)CCCC2=O.COc1cccc(C(=O)O)c1.COc1cccc(C(=O)O)c1OC.COc1cccc(C(C)=O)c1.COc1cccc(C=CC(=O)O)c1.COc1cccc(C=O)c1.COc1cccc(C=O)c1O.COc1cccc(CC(=O)O)c1.COc1cccc(OC)c1C(=O)O.COc1ccccc1C(=O)O.COc1ccccc1C(=O)c1ccccc1.COc1ccccc1C(C)=O.COc1ccccc1C=CC=C1CC(C)CC(=CC=Cc2ccccc2OC)C1=O.COc1ccccc1C=CC=C1CCC(=CC=Cc2ccccc2OC)C1=O.COc1ccccc1C=CC=C1CCCCC(=CC=Cc2ccccc2OC)C1=O.COc1ccccc1C=O.COc1ccccc1CC(=O)O.COc1ccccc1CCC(=O)O.Cc1ccc(C)c(OCCCC(C)(C)C(=O)O)c1.Cc1ccc(OCCC(=O)O)cc1.O=C(O)COCC(=O)O.O=C(O)c1ccc(OCCOc2ccc(C(=O)O)cc2)cc1'

# %%
'.'.join([x[0] for x in result if x[1] == 'Acyclic_Ether' and x[0].count('O') >=2 and x[0].count('1') == 0])
# Out:
# 'C=C(OC)C(C)C(C)=O.C=CCOC(C)OCC=C.C=COCCCCOC=C.C=COCCOC.C=COCCOC(C)C.C=COCCOC=C.C=COCCOCC.C=COCCOCC(C)C.C=COCCOCCC.C=COCCOCCCC.C=COCCOCCOCCO.C=COCCOCCOCCOC=C.CC(C)CCOCC(O)CO.CC(C)COC(C)OCC(C)C.CC(C)COCCO.CC(C)COCOCC(C)C.CC(C)OC(C)OC(C)C.CC(C)OC(OC(C)C)C(C)C.CC(C)OCCO.CC(C)OCCOCCO.CC(O)COC(C)(C)C.CC(O)COC(C)CO.CC(O)COC(C)COC(C)COC(C)COC(C)C.CC(O)COCC(C)O.CC=COC(C)(C)OC.CCC(C)(OC)OC.CCC(C)C(OC)OC.CCC(C)COCCOCCO.CCC(C)OC(C)OC(C)CC.CCC(C)OCCO.CCC(OC(C)C)OC(C)C.CCC(OC)OC.CCCC(C)CCCOCCCCCCOCCCC(C)CCC.CCCC(CC(OCC)OCC)OCC.CCCC(OC(C)C)OC(C)C.CCCC(OC)OC.CCCC(OCC(C)C)OCC(C)C.CCCC(OCC)OCC.CCCCC(C)(OC)OC.CCCCC(CC)C(OCC)OCC.CCCCC(CC)COCCCCCCO.CCCCC(CC)COCCOCCO.CCCCC(OCC)OCC.CCCCCC(CC)COCCCCCCOCC(CC)CCCCC.CCCCCCC(OCC)OCC.CCCCCCCCCCCCCCCCCCOCCO.CCCCCCCCCCCCCCCCOCCO.CCCCCCCCCCCCCCOCC(O)CO.CCCCCCCCCCCCCOCC(O)CO.CCCCCCCCCCCCOCC(O)CO.CCCCCCCCCCCOCC(O)CO.CCCCCCCCCCOCC(O)CO.CCCCCCCCCCOCCCO.CCCCCCCCCCOCCO.CCCCCCCCCOCC(O)CO.CCCCCCCCOCC(O)CO.CCCCCCCCOCCO.CCCCCCCCOCCOCCO.CCCCCCCCOCCOCCOCCO.CCCCCCCCOCCOCCOCCOCCO.CCCCCCCOCC(O)CO.CCCCCCCOCCO.CCCCCCCOCCOCCO.CCCCCCCOCCOCCOCCO.CCCCCCCOCCOCCOCCOCCO.CCCCCCOC(C)CCC(C)OCCCCCC.CCCCCCOCC(O)CO.CCCCCCOCCCCCCOCCCCCC.CCCCCCOCCO.CCCCCCOCCOCCO.CCCCCCOCCOCCOCCCCCC.CCCCCCOCCOCCOCCO.CCCCCCOCCOCCOCCOCCO.CCCCCCOCOCCCCCC.CCCCCOC(C)OCCCCC.CCCCCOCC(O)CO.CCCCCOCC(O)COC(C)(C)C.CCCCCOCC(O)COOC(C)(C)C.CCCCCOCCO.CCCCCOCCOCCO.CCCCCOCCOCCOCCO.CCCCCOCCOCCOCCOCCO.CCCCCOCCOCCOCCOCCOCCO.CCCCCOCOCCCCC.CCCCOC(C)(C)OCCCC.CCCCOC(C)C(=O)O.CCCCOC(C)CC(OCCCC)OCCCC.CCCCOC(C)COCC(C)O.CCCCOC(C)OCCCC.CCCCOC(CC)OCCCC.CCCCOC(CCC)OCCCC.CCCCOC(OOC(C)(C)C)C(C)O.CCCCOCC(C)O.CCCCOCC(C)OCC(C)O.CCCCOCC(C)OCC(C)OCC(C)O.CCCCOCC(C)OCC(C)OCC(C)OCCCC.CCCCOCC(O)COC(C)(C)C.CCCCOCCCCCOC.CCCCOCCCCOC.CCCCOCCCCOCCCC.CCCCOCCCOCCCO.CCCCOCCO.CCCCOCCOC.CCCCOCCOCC.CCCCOCCOCCCC.CCCCOCCOCCOCCCC.CCCCOCCOCCOCCO.CCCCOCCOCCOCCOCCCC.CCCCOCCOCCOCCOCCO.CCCCOCCOCCOCCOCCOCCO.CCCCOCCOCCOCOCCOCCOCCCC.CCCCOCOCCCC.CCCOC(C)OCCC.CCCOC(CCC)OCCC.CCCOCC(C)O.CCCOCC(C)OCC(C)O.CCCOCC(O)COC(C)(C)C.CCCOCC(O)COOC(C)(C)C.CCCOCCCCOCCC.CCCOCCCO.CCCOCCCOC.CCCOCCO.CCCOCCOCC.CCCOCCOCCC.CCCOCCOCCO.CCCOCCOCCOCCC.CCOC(C)(C)CO.CCOC(C)(C)OCC.CCOC(C)(OCC)OCC.CCOC(C)COC(C)CO.CCOC(C)OCC.CCOC(CC)OCC.CCOC(OCC)(OCC)OCC.CCOC(OCC)C(C)C.CCOC(OCC)OCC.CCOCC(C)(C)O.CCOCC(C)O.CCOCC(O)COC(C)(C)C.CCOCC(O)COOC(C)(C)C.CCOCCC(C)CCO.CCOCCCCCCOC.CCOCCCCCOC.CCOCCCCCOCC.CCOCCCCOC.CCOCCCCOCC.CCOCCCO.CCOCCCOCC.CCOCCO.CCOCCOC.CCOCCOC(C)(C)C.CCOCCOC(C)C.CCOCCOCC.CCOCCOCCO.CCOCCOCCOCC.CCOCCOCCOCCO.CCOCCOCCOCCOCCOCC.CCOCOCC.CCOCOCOCC.CCOCOCOCOCC.CCOCOCOCOCOCC.COC(C)(C)CO.COC(C)(C)OC.COC(C)(OC)OC.COC(C)=CC=C(C)OC.COC(C)CCCO.COC(C)CCO.COC(C)COC(C)CO.COC(C)OC.COC(CC(C)(C)C)OC.COC(CC(C)C)OC.COC(CO)CCO.COC(OC)(OC)OC.COC(OC)C(C)(C)C.COC(OC)C(C)C.COC(OC)OC.COCC(C)(C)O.COCC(C)(CO)COC.COCC(C)=O.COCC(C)O.COCC(C)OC.COCC(O)CCO.COCC(O)COOC(C)(C)C.COCC=O.COCCC(O)CO.COCCC(O)COC.COCCCCCCOC.COCCCCCOC.COCCCCO.COCCCCOC.COCCCO.COCCO.COCCOC.COCCOC(C)(C)C.COCCOCCO.COCCOCCOC.COCCOCCOC(C)(C)C.COCCOCCOCCO.COCCOCCOCCOC.COCCOCCOCCOCCO.COCCOCCOCCOCCOC.COCCOCCOCCOCCOCCOC.COCOC.O=C(O)COCC(=O)O.OCCCOCCCO.OCCOCC(O)CO.OCCOCCO.OCCOCCOCCO.OCCOCCOCCOCCO.OCCOCCOCCOCCOCCO'

# %%
d
